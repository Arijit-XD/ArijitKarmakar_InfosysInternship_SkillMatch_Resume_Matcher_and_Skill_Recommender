# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_breast_cancer

import matplotlib.pyplot as plt
import numpy as np
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(cancer.data, cancer.target, random_state=0)

# %%
forest = RandomForestClassifier(n_estimators=50, random_state=0)
forest.fit(X_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=0)

# %%
print ('Accuracy on the training subset: ( :.3f)', format(forest.score(X_train,y_train)))
print ('Accuracy on the training subset: ( :.3f)', format(forest.score(X_test, y_test)))
# Out:
# Accuracy on the training subset: ( :.3f) 1.0
# Accuracy on the training subset: ( :.3f) 0.965034965034965

# %%
n_features = cancer.data.shape[1]
plt.barh(range(n_features), forest.feature_importances_, align='center')
plt.yticks(np.arange(n_features), cancer.feature_names)
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# Diabetes Dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\ARIJIT\OneDrive\Desktop\ACADEMICS\Internship\Infosys Internship\ArijitKarmakar_InfosysInternship_SkillMatch_Resume_Matcher_and_Skill_Recommender\diabetes.csv")

# %%
X = df.drop("Outcome", axis=1)
y = df["Outcome"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = RandomForestClassifier(n_estimators=50, random_state=0)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=0)

# %%
pred = model.predict(X_test)

# %%
print("Accuracy:", accuracy_score(y_test, pred))
print("\nConfusion Matrix:\n", confusion_matrix(y_test, pred))
print("\nClassification Report:\n", classification_report(y_test, pred))
# Out:
# d:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2732: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 print ('Accuracy on the training subset: ( :.3f)', format(forest.score(X_train,y_train)))
#       2 print ('Accuracy on the training subset: ( :.3f)', format(forest.score(X_test, y_test)))
#
# File d:\anaconda3\Lib\site-packages\sklearn\base.py:572, in ClassifierMixin.score(self, X, y, sample_weight)
#     547 """
#     548 Return the mean accuracy on the given test data and labels.
#     549
#    (...)
#     568     Mean accuracy of ``self.predict(X)`` w.r.t. `y`.
#     569 """
#     570 from .metrics import accuracy_score
# --> 572 return accuracy_score(y, self.predict(X), sample_weight=sample_weight)
#
# File d:\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:904, in ForestClassifier.predict(self, X)
#     883 def predict(self, X):
#     884     """
#     885     Predict class for X.
#     886
#    (...)
#     902         The predicted classes.
#     903     """
# --> 904     proba = self.predict_proba(X)
#     906     if self.n_outputs_ == 1:
#     907         return self.classes_.take(np.argmax(proba, axis=1), axis=0)
#
# File d:\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:946, in ForestClassifier.predict_proba(self, X)
#     944 check_is_fitted(self)
#     945 # Check data
# --> 946 X = self._validate_X_predict(X)
#     948 # Assign chunk of trees to jobs
#     949 n_jobs, _, _ = _partition_estimators(self.n_estimators, self.n_jobs)
#
# File d:\anaconda3\Lib\site-packages\sklearn\ensemble\_forest.py:638, in BaseForest._validate_X_predict(self, X)
#     635 else:
#     636     ensure_all_finite = True
# --> 638 X = validate_data(
#     639     self,
#     640     X,
#     641     dtype=DTYPE,
#     642     accept_sparse="csr",
#     643     reset=False,
#     644     ensure_all_finite=ensure_all_finite,
#     645 )
#     646 if issparse(X) and (X.indices.dtype != np.intc or X.indptr.dtype != np.intc):
#     647     raise ValueError("No support for np.int64 index based sparse matrices")
#
# File d:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2965, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2962     out = X, y
#    2964 if not no_val_X and check_params.get("ensure_2d", True):
# -> 2965     _check_n_features(_estimator, X, reset=reset)
#    2967 return out
#
# File d:\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2829, in _check_n_features(estimator, X, reset)
#    2826     return
#    2828 if n_features != estimator.n_features_in_:
# -> 2829     raise ValueError(
#    2830         f"X has {n_features} features, but {estimator.__class__.__name__} "
#    2831         f"is expecting {estimator.n_features_in_} features as input."
#    2832     )
#
# ValueError: X has 8 features, but RandomForestClassifier is expecting 30 features as input.

# %%
n_features = X.shape[1]
plt.barh(range(n_features), model.feature_importances_, align='center')
plt.yticks(np.arange(n_features), X.columns)
plt.xlabel('Feature Importance')
plt.ylabel('Feature')
plt.title('Random Forest Feature Importance')
plt.show()
